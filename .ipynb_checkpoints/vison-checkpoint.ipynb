# %%
# !pip install shapely
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support pip 21.0 will remove support for this functionality.
# ...
#      |████████████████████████████████| 1.0 MB 117 kB/s eta 0:00:01
# ...

# %%
import numpy as np
import json
import pandas as pd
from shapely.wkt import dumps, loads
from shapely.geometry import Polygon

# %%
df = open('/home/ayush/Documents/VisionBeyondLimits/Labels/mexico-earthquake_00000001_post_disaster.json')
data = json.load(df)
print(data)
# Out:
# {u'features': {u'lng_lat': [{u'properties': {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'f61736db-c71a-4eac-95ab-704909c1a133'}, u'wkt': u'POLYGON ((-99.22391735003816 19.33270821533729, -99.22399703307177 19.33267259856737, -99.2240258747197 19.33268538911176, -99.22403039481853 19.33269735447365, -99.22408170520377 19.3326733495849, -99.22413409480619 19.33278016836537, -99.22391756481488 19.33286579030988, -99.22391735003816 19.33270821533729))'}, {u'properties': {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'528c7a1e-46ca-4795-bcdd-92f1ec30889a'}, u'wkt': u'POLYGON ((-99.22391724242834 19.33262926537574, -99.22394153057537 19.33261561822526, -99.22394978080557 19.33262876972653, -99.22392120853468 19.33264649076795, -99.22392250668834 19.33264525527029, -99.22391724986738 19.33263472316609, -99.22391724242834 19.33262926537574))'}, {u'properties': {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'fed2b4e0-d48e-42e3-a555-5
# ...

# %%
for a in data:
    print(a)
# Out:
# features
# metadata

# %%
for b in data['features']['xy']:
    print(b['properties'])
# Out:
# {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'f61736db-c71a-4eac-95ab-704909c1a133'}
# {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'528c7a1e-46ca-4795-bcdd-92f1ec30889a'}
# {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'fed2b4e0-d48e-42e3-a555-5d5f1faf3585'}
# {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'93a06eb0-d405-4244-bb38-dc17cfc2d07d'}
# {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'77b2de73-8fbe-4e04-adde-3f58fca98a9c'}
# {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'7cf6a3c9-5b3f-4bb1-b452-fa06bbd9af43'}
# {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'8de16318-c467-456a-87e4-88c2058fda7b'}
# {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'd45f2479-e193-4e9b-ba1f-96589b47812a'}
# {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'2a1af8b3-71db-4725-8bd9-93722f251732'}
# ...

# %%
a =[]
b = []
for coordinate in data['features']['xy']:
    #print(coordinate['wkt'])
    a.append(coordinate['wkt'])
    #print("--")

# %%
type(a)
# Out:
# list

# %%
a[0]
# Out:
# u'POLYGON ((1022.975467185924 739.2521401796066, 1005.679622937569 747.3688275618451, 999.4269058143009 744.4378664097038, 998.4499187631066 741.7023026698211, 987.312266386992 747.1734301524717, 975.9792166006625 722.7487538884745, 1022.975464541918 703.2434419004524, 1022.975467185924 739.2521401796066))'

# %%
for points in a:
    s2 = points.split("POLYGON")[1]
    #print(s2)
    s3 = s2.split("(")[2]
    print(s3)
    #print(points.replace('POLYGON'," "))
    #points = points.replace('POLYGON'," ")
    #points[1] =tmp;
# Out:
# 1022.975467185924 739.2521401796066, 1005.679622937569 747.3688275618451, 999.4269058143009 744.4378664097038, 998.4499187631066 741.7023026698211, 987.312266386992 747.1734301524717, 975.9792166006625 722.7487538884745, 1022.975464541918 703.2434419004524, 1022.975467185924 739.2521401796066))
# 1022.975468683253 757.293617586021, 1017.702703821244 760.405413185511, 1015.916903415412 757.3977493388959, 1022.120210095989 753.3562010488236, 1021.838241609377 753.6381695327908, 1022.975468576386 756.0464149420958, 1022.975468683253 757.293617586021))
# 1003.707439416812 761.8626278668446, 1013.42834562603 757.9595367373, 1014.974853431919 761.7889846358805, 1005.033017535819 766.3548648248687, 1002.97100713013 762.0835575520437, 1003.707439416812 761.8626278668446))
# ...

# %%
p=[] 
p.append(Polygon([(1022.975467185924, 739.2521401796066), (1005.679622937569, 747.3688275618451), (999.4269058143009, 744.4378664097038), (998.4499187631066, 741.7023026698211), (987.312266386992, 747.1734301524717), (975.9792166006625, 722.7487538884745), (1022.975464541918, 703.2434419004524), (1022.975467185924, 739.2521401796066)]))
p.append(Polygon([(989.4085904562331, 842.2231917626796), (998.8075399724552, 838.839569934877), (998.9015294663095, 843.8210131808031), (991.1004013690522, 846.7346875311596), (989.3146009585321, 842.693139239164), (989.4085904562331, 842.2231917626796)]))

# %%
import matplotlib.pyplot as plt
for d in p:
    print(d)
    x,y = d.exterior.xy
    print(plt.plot(x,y))
# Out:
# POLYGON ((1022.975467185924 739.2521401796066, 1005.679622937569 747.3688275618451, 999.4269058143009 744.4378664097038, 998.4499187631066 741.7023026698211, 987.312266386992 747.1734301524717, 975.9792166006625 722.7487538884745, 1022.975464541918 703.2434419004524, 1022.975467185924 739.2521401796066))
# ...
# POLYGON ((989.4085904562331 842.2231917626796, 998.8075399724552 838.839569934877, 998.9015294663095 843.8210131808031, 991.1004013690522 846.7346875311596, 989.3146009585321 842.693139239164, 989.4085904562331 842.2231917626796))
# ...

# %%
from matplotlib import image
img = image.imread('/home/ayush/Documents/VisionBeyondLimits/Images/mexico-earthquake_00000001_post_disaster.png')
for d in p:
    print(d)
    x,y = d.exterior.xy
    plt.plot(x,y,color="white")
    plt.imshow(img)
plt.show()
# Out:
# POLYGON ((1022.975467185924 739.2521401796066, 1005.679622937569 747.3688275618451, 999.4269058143009 744.4378664097038, 998.4499187631066 741.7023026698211, 987.312266386992 747.1734301524717, 975.9792166006625 722.7487538884745, 1022.975464541918 703.2434419004524, 1022.975467185924 739.2521401796066))
# POLYGON ((989.4085904562331 842.2231917626796, 998.8075399724552 838.839569934877, 998.9015294663095 843.8210131808031, 991.1004013690522 846.7346875311596, 989.3146009585321 842.693139239164, 989.4085904562331 842.2231917626796))

# %%
df = open('/home/ayush/Documents/VisionBeyondLimits/Labels/mexico-earthquake_00000075_post_disaster.json')
data = json.load(df)
print(data)
# Out:
# {u'features': {u'lng_lat': [{u'properties': {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'77d281b1-fc13-4b51-b895-ba15170ac82f'}, u'wkt': u'POLYGON ((-99.15079977440244 19.28751152255812, -99.15085217124434 19.2873277095883, -99.15099316622252 19.28735481824648, -99.15101938428721 19.28728446495677, -99.15104565642362 19.28727309942681, -99.151315693529 19.28732051995137, -99.15128471569369 19.28741129608072, -99.15152151302233 19.28747312762031, -99.15153170599642 19.28748691141069, -99.15149125878251 19.28768470774332, -99.15145201144071 19.28769413423406, -99.15110306223033 19.2876205289957, -99.15097482941744 19.28820335029345, -99.15047297162572 19.28809713257716, -99.15064917429459 19.2874322401505, -99.15076388468613 19.28745710189725, -99.15074959234667 19.28750475769059, -99.15079977440244 19.28751152255812))'}, {u'properties': {u'subtype': u'no-damage', u'feature_type': u'building', u'uid': u'dd733b50-8117-4266-8079-e8ecd867ee9b'}, u'wkt': u'POLYGON ((-
# ...

# %%
a
# Out:
# [u'POLYGON ((1022.975467185924 739.2521401796066, 1005.679622937569 747.3688275618451, 999.4269058143009 744.4378664097038, 998.4499187631066 741.7023026698211, 987.312266386992 747.1734301524717, 975.9792166006625 722.7487538884745, 1022.975464541918 703.2434419004524, 1022.975467185924 739.2521401796066))',
#  u'POLYGON ((1022.975468683253 757.293617586021, 1017.702703821244 760.405413185511, 1015.916903415412 757.3977493388959, 1022.120210095989 753.3562010488236, 1021.838241609377 753.6381695327908, 1022.975468576386 756.0464149420958, 1022.975468683253 757.293617586021))',
#  u'POLYGON ((1003.707439416812 761.8626278668446, 1013.42834562603 757.9595367373, 1014.974853431919 761.7889846358805, 1005.033017535819 766.3548648248687, 1002.97100713013 762.0835575520437, 1003.707439416812 761.8626278668446))',
# ...

# %%
# !pip install geomet
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support pip 21.0 will remove support for this functionality.
# ...
#      |████████████████████████████████| 82 kB 47 kB/s  eta 0:00:01
# ...
#   Created wheel for geomet: filename=geomet-0.3.0-py2-none-any.whl size=23696 sha256=dad13b27e317122e9d5b4e5f49a1f5da30a1a3c002fa1276791db7c10d7a5a57
#   Stored in directory: /home/ayush/.cache/pip/wheels/bc/cb/8d/9739aeece147bca820b713bfaae46aa17623fd7eaf50566bc4
# Successfully built geomet
# ...

# %%
from geomet import wkt

# %%
from shapely import wkt
p1=[]
for o in a:
    p1.append(wkt.loads(o))

# %%
from matplotlib import image
from shapely.geometry import Polygon as POLYGON
img = image.imread('/home/ayush/Documents/VisionBeyondLimits/Images/mexico-earthquake_00000001_post_disaster.png')

for k in p1:
    x,y = k.exterior.xy
    plt.plot(x,y,color="white")
    plt.imshow(img)
plt.show()
