# %%
import numpy as np
import pickle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# Import necessary items from Keras
from keras.models import Sequential
from keras.layers import Activation, Dropout, UpSampling2D
from keras.layers import Conv2DTranspose, Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
input=tf.keras.layers.Input(shape=(288,288,3,))
x=Conv2D(64,(2,2),strides=(2,2))(input)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=MaxPooling2D(pool_size=(2,2))(x)
o=x
x=Conv2D(64,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(64,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(64,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(64,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(64,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
o=Conv2D(128,(2,2),strides=(2,2),padding='same')(o)
o1=x
x=Conv2D(128,(2,2),strides=(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(128,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(128,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(128,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(128,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(128,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(128,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(128,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
o=Conv2D(256,(2,2),strides=(2,2),padding='same')(o)
x=BatchNormalization()(x)
x=Activation('relu')(x)
o2=x
x=Conv2D(256,(2,2),strides=(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
o=Conv2D(512,(2,2),strides=(2,2),padding='same')(o)
x=BatchNormalization()(x)
x=Activation('relu')(x)
o3=x
x=Conv2D(512,(2,2),strides=(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(512,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(512,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(512,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
o=x
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(512,(2,2),padding='same')(x)
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=Conv2D(512,(2,2),padding='same')(x)
x=tf.keras.layers.Add()([o,x])
x=BatchNormalization()(x)
x=Activation('relu')(x)
x=tf.keras.layers.UpSampling2D(size=(2,2))(x)
x=tf.keras.layers.concatenate([x,o3])
x=Conv2D(256,(2,2),padding='same')(x)
x=Activation('relu')(x)
x=Conv2D(256,(2,2),padding='same')(x)
x=Activation('relu')(x)
x=tf.keras.layers.UpSampling2D(size=(2,2))(x)
x=tf.keras.layers.concatenate([x,o2])
x=Conv2D(128,(2,2),padding='same')(x)
x=Activation('relu')(x)
x=Conv2D(128,(2,2),padding='same')(x)
x=Activation('relu')(x)
x=tf.keras.layers.UpSampling2D(size=(2,2))(x)
x=tf.keras.layers.concatenate([x,o1])
x=Conv2D(64,(2,2),padding='same')(x)
x=Activation('relu')(x)
x=Conv2D(64,(2,2),padding='same')(x)
x=Activation('relu')(x)
x=tf.keras.layers.UpSampling2D(size=(2,2))(x)
x=Conv2D(32,(2,2),padding='same')(x)
x=Activation('relu')(x)
x=Conv2D(32,(2,2),padding='same')(x)
x=Activation('relu')(x)
x=tf.keras.layers.UpSampling2D(size=(2,2))(x)
x=Conv2D(16,(2,2),padding='same')(x)
x=Activation('relu')(x)
x=Conv2D(16,(2,2),padding='same')(x)
x=Activation('relu')(x)
x=Conv2D(1,(2,2),padding='same')(x)
x=Activation('relu')(x)
model=tf.keras.Model(inputs=input,outputs=x)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 288, 288, 3  0           []
#                                 )]
#
#  conv2d_151 (Conv2D)            (None, 144, 144, 64  832         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_132 (Batch  (None, 144, 144, 64  256        ['conv2d_151[0][0]']
#  Normalization)                 )
#
#  activation_143 (Activation)    (None, 144, 144, 64  0           ['batch_normalization_132[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 72, 72, 64)  0           ['activation_143[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 72, 72, 64)   16448       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_133 (Batch  (None, 72, 72, 64)  256         ['conv2d_152[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_133[0][0]']
#
#  add_64 (Add)                   (None, 72, 72, 64)   0           ['max_pooling2d_4[0][0]',
#                                                                   'activation_144[0][0]']
#
#  batch_normalization_134 (Batch  (None, 72, 72, 64)  256         ['add_64[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_134[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 72, 72, 64)   16448       ['activation_145[0][0]']
#
#  batch_normalization_135 (Batch  (None, 72, 72, 64)  256         ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_135[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 72, 72, 64)   16448       ['activation_146[0][0]']
#
#  add_65 (Add)                   (None, 72, 72, 64)   0           ['add_64[0][0]',
#                                                                   'conv2d_154[0][0]']
#
#  batch_normalization_136 (Batch  (None, 72, 72, 64)  256         ['add_65[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_136[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 72, 72, 64)   16448       ['activation_147[0][0]']
#
#  batch_normalization_137 (Batch  (None, 72, 72, 64)  256         ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_137[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 72, 72, 64)   16448       ['activation_148[0][0]']
#
#  add_66 (Add)                   (None, 72, 72, 64)   0           ['add_65[0][0]',
#                                                                   'conv2d_156[0][0]']
#
#  batch_normalization_138 (Batch  (None, 72, 72, 64)  256         ['add_66[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_138[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 36, 36, 128)  32896       ['activation_149[0][0]']
#
#  batch_normalization_139 (Batch  (None, 36, 36, 128)  512        ['conv2d_158[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 36, 36, 128)  0           ['batch_normalization_139[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 36, 36, 128)  32896       ['add_66[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 36, 36, 128)  65664       ['activation_150[0][0]']
#
#  add_67 (Add)                   (None, 36, 36, 128)  0           ['conv2d_157[0][0]',
#                                                                   'conv2d_159[0][0]']
#
#  batch_normalization_140 (Batch  (None, 36, 36, 128)  512        ['add_67[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 36, 36, 128)  0           ['batch_normalization_140[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 36, 36, 128)  65664       ['activation_151[0][0]']
#
#  batch_normalization_141 (Batch  (None, 36, 36, 128)  512        ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 36, 36, 128)  0           ['batch_normalization_141[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 36, 36, 128)  65664       ['activation_152[0][0]']
#
#  add_68 (Add)                   (None, 36, 36, 128)  0           ['add_67[0][0]',
#                                                                   'conv2d_161[0][0]']
#
#  batch_normalization_142 (Batch  (None, 36, 36, 128)  512        ['add_68[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 36, 36, 128)  0           ['batch_normalization_142[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 36, 36, 128)  65664       ['activation_153[0][0]']
#
#  batch_normalization_143 (Batch  (None, 36, 36, 128)  512        ['conv2d_162[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 36, 36, 128)  0           ['batch_normalization_143[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 36, 36, 128)  65664       ['activation_154[0][0]']
#
#  add_69 (Add)                   (None, 36, 36, 128)  0           ['add_68[0][0]',
#                                                                   'conv2d_163[0][0]']
#
#  batch_normalization_144 (Batch  (None, 36, 36, 128)  512        ['add_69[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 36, 36, 128)  0           ['batch_normalization_144[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 36, 36, 128)  65664       ['activation_155[0][0]']
#
#  batch_normalization_145 (Batch  (None, 36, 36, 128)  512        ['conv2d_164[0][0]']
#  Normalization)
#
#  activation_156 (Activation)    (None, 36, 36, 128)  0           ['batch_normalization_145[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 36, 36, 128)  65664       ['activation_156[0][0]']
#
#  add_70 (Add)                   (None, 36, 36, 128)  0           ['add_69[0][0]',
#                                                                   'conv2d_165[0][0]']
#
#  batch_normalization_146 (Batch  (None, 36, 36, 128)  512        ['add_70[0][0]']
#  Normalization)
#
#  activation_157 (Activation)    (None, 36, 36, 128)  0           ['batch_normalization_146[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 18, 18, 256)  131328      ['activation_157[0][0]']
#
#  batch_normalization_147 (Batch  (None, 18, 18, 256)  1024       ['conv2d_167[0][0]']
#  Normalization)
#
#  activation_158 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_147[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 18, 18, 256)  131328      ['add_70[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_158[0][0]']
#
#  add_71 (Add)                   (None, 18, 18, 256)  0           ['conv2d_166[0][0]',
#                                                                   'conv2d_168[0][0]']
#
#  batch_normalization_148 (Batch  (None, 18, 18, 256)  1024       ['add_71[0][0]']
#  Normalization)
#
#  activation_159 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_159[0][0]']
#
#  batch_normalization_149 (Batch  (None, 18, 18, 256)  1024       ['conv2d_169[0][0]']
#  Normalization)
#
#  activation_160 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_149[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_160[0][0]']
#
#  add_72 (Add)                   (None, 18, 18, 256)  0           ['add_71[0][0]',
#                                                                   'conv2d_170[0][0]']
#
#  batch_normalization_150 (Batch  (None, 18, 18, 256)  1024       ['add_72[0][0]']
#  Normalization)
#
#  activation_161 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_150[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_161[0][0]']
#
#  batch_normalization_151 (Batch  (None, 18, 18, 256)  1024       ['conv2d_171[0][0]']
#  Normalization)
#
#  activation_162 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_151[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_162[0][0]']
#
#  add_73 (Add)                   (None, 18, 18, 256)  0           ['add_72[0][0]',
#                                                                   'conv2d_172[0][0]']
#
#  batch_normalization_152 (Batch  (None, 18, 18, 256)  1024       ['add_73[0][0]']
#  Normalization)
#
#  activation_163 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_152[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_163[0][0]']
#
#  batch_normalization_153 (Batch  (None, 18, 18, 256)  1024       ['conv2d_173[0][0]']
#  Normalization)
#
#  activation_164 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_153[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_164[0][0]']
#
#  add_74 (Add)                   (None, 18, 18, 256)  0           ['add_73[0][0]',
#                                                                   'conv2d_174[0][0]']
#
#  batch_normalization_154 (Batch  (None, 18, 18, 256)  1024       ['add_74[0][0]']
#  Normalization)
#
#  activation_165 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_154[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_165[0][0]']
#
#  batch_normalization_155 (Batch  (None, 18, 18, 256)  1024       ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_166 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_155[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_166[0][0]']
#
#  add_75 (Add)                   (None, 18, 18, 256)  0           ['add_74[0][0]',
#                                                                   'conv2d_176[0][0]']
#
#  batch_normalization_156 (Batch  (None, 18, 18, 256)  1024       ['add_75[0][0]']
#  Normalization)
#
#  activation_167 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_156[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_167[0][0]']
#
#  batch_normalization_157 (Batch  (None, 18, 18, 256)  1024       ['conv2d_177[0][0]']
#  Normalization)
#
#  activation_168 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_157[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_168[0][0]']
#
#  add_76 (Add)                   (None, 18, 18, 256)  0           ['add_75[0][0]',
#                                                                   'conv2d_178[0][0]']
#
#  batch_normalization_158 (Batch  (None, 18, 18, 256)  1024       ['add_76[0][0]']
#  Normalization)
#
#  activation_169 (Activation)    (None, 18, 18, 256)  0           ['batch_normalization_158[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 9, 9, 512)    524800      ['activation_169[0][0]']
#
#  batch_normalization_159 (Batch  (None, 9, 9, 512)   2048        ['conv2d_180[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 9, 9, 512)    0           ['batch_normalization_159[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 9, 9, 512)    524800      ['add_76[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 9, 9, 512)    1049088     ['activation_170[0][0]']
#
#  add_77 (Add)                   (None, 9, 9, 512)    0           ['conv2d_179[0][0]',
#                                                                   'conv2d_181[0][0]']
#
#  batch_normalization_160 (Batch  (None, 9, 9, 512)   2048        ['add_77[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 9, 9, 512)    0           ['batch_normalization_160[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 9, 9, 512)    1049088     ['activation_171[0][0]']
#
#  batch_normalization_161 (Batch  (None, 9, 9, 512)   2048        ['conv2d_182[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 9, 9, 512)    0           ['batch_normalization_161[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 9, 9, 512)    1049088     ['activation_172[0][0]']
#
#  add_78 (Add)                   (None, 9, 9, 512)    0           ['add_77[0][0]',
#                                                                   'conv2d_183[0][0]']
#
#  batch_normalization_162 (Batch  (None, 9, 9, 512)   2048        ['add_78[0][0]']
#  Normalization)
#
#  activation_173 (Activation)    (None, 9, 9, 512)    0           ['batch_normalization_162[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 9, 9, 512)    1049088     ['activation_173[0][0]']
#
#  batch_normalization_163 (Batch  (None, 9, 9, 512)   2048        ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_174 (Activation)    (None, 9, 9, 512)    0           ['batch_normalization_163[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 9, 9, 512)    1049088     ['activation_174[0][0]']
#
#  add_79 (Add)                   (None, 9, 9, 512)    0           ['add_78[0][0]',
#                                                                   'conv2d_185[0][0]']
#
#  batch_normalization_164 (Batch  (None, 9, 9, 512)   2048        ['add_79[0][0]']
#  Normalization)
#
#  activation_175 (Activation)    (None, 9, 9, 512)    0           ['batch_normalization_164[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 18, 18, 512)  0          ['activation_175[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 18, 18, 768)  0           ['up_sampling2d_8[0][0]',
#                                                                   'activation_169[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 18, 18, 256)  786688      ['concatenate_6[0][0]']
#
#  activation_176 (Activation)    (None, 18, 18, 256)  0           ['conv2d_186[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 18, 18, 256)  262400      ['activation_176[0][0]']
#
#  activation_177 (Activation)    (None, 18, 18, 256)  0           ['conv2d_187[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 36, 36, 256)  0          ['activation_177[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 36, 36, 384)  0           ['up_sampling2d_9[0][0]',
#                                                                   'activation_157[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 36, 36, 128)  196736      ['concatenate_7[0][0]']
#
#  activation_178 (Activation)    (None, 36, 36, 128)  0           ['conv2d_188[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 36, 36, 128)  65664       ['activation_178[0][0]']
#
#  activation_179 (Activation)    (None, 36, 36, 128)  0           ['conv2d_189[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 72, 72, 128)  0          ['activation_179[0][0]']
#  )
#
#  concatenate_8 (Concatenate)    (None, 72, 72, 192)  0           ['up_sampling2d_10[0][0]',
#                                                                   'activation_149[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 72, 72, 64)   49216       ['concatenate_8[0][0]']
#
#  activation_180 (Activation)    (None, 72, 72, 64)   0           ['conv2d_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 72, 72, 64)   16448       ['activation_180[0][0]']
#
#  activation_181 (Activation)    (None, 72, 72, 64)   0           ['conv2d_191[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 144, 144, 64  0          ['activation_181[0][0]']
#  )                              )
#
#  conv2d_192 (Conv2D)            (None, 144, 144, 32  8224        ['up_sampling2d_11[0][0]']
#                                 )
#
#  activation_182 (Activation)    (None, 144, 144, 32  0           ['conv2d_192[0][0]']
#                                 )
#
#  conv2d_193 (Conv2D)            (None, 144, 144, 32  4128        ['activation_182[0][0]']
#                                 )
#
#  activation_183 (Activation)    (None, 144, 144, 32  0           ['conv2d_193[0][0]']
#                                 )
#
#  up_sampling2d_12 (UpSampling2D  (None, 288, 288, 32  0          ['activation_183[0][0]']
#  )                              )
#
#  conv2d_194 (Conv2D)            (None, 288, 288, 16  2064        ['up_sampling2d_12[0][0]']
#                                 )
#
#  activation_184 (Activation)    (None, 288, 288, 16  0           ['conv2d_194[0][0]']
#                                 )
#
#  conv2d_195 (Conv2D)            (None, 288, 288, 16  1040        ['activation_184[0][0]']
#                                 )
#
#  activation_185 (Activation)    (None, 288, 288, 16  0           ['conv2d_195[0][0]']
#                                 )
#
#  conv2d_196 (Conv2D)            (None, 288, 288, 1)  65          ['activation_185[0][0]']
#
#  activation_186 (Activation)    (None, 288, 288, 1)  0           ['conv2d_196[0][0]']
#
# ==================================================================================================
# Total params: 11,475,745
# Trainable params: 11,460,513
# Non-trainable params: 15,232
# __________________________________________________________________________________________________
